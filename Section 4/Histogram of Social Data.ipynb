# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
df = pd.read_table('wiki-Vote.txt', sep=r"\s+", index_col=0)

# %%
print(df.head())
# Out:
#             ToNodeId
# FromNodeId
# 30              1412
# 30              3352
# 30              5254
# 30              5543
# 30              7478

# %%
print(df.describe())
# Out:
#             ToNodeId
# count  103689.000000
# mean     3580.347018
# std      2204.045658
# min         3.000000
# 25%      1746.000000
# 50%      3260.000000
# 75%      5301.000000
# max      8297.000000

# %%
from_counter = {}
to_counter = {}
for index, row in df.iterrows():
        ton = row['ToNodeId']
        fromn = index

        if fromn in from_counter:

            from_counter[fromn] = from_counter.get(fromn) + 1
        else:

            from_counter[fromn] = 1

        if ton in to_counter:

            to_counter[ton] = to_counter.get(ton) + 1
        else:

            to_counter[ton] = 1
print(from_counter)
print(to_counter)
# Out:
# {30: 5, 3: 23, 25: 90, 4: 29, 5: 23, 6: 302, 7: 24, 8: 182, 9: 81, 10: 86, 11: 743, 12: 65, 13: 11, 14: 114, 15: 50, 16: 15, 17: 45, 18: 12, 19: 39, 20: 187, 21: 76, 22: 2, 23: 74, 24: 309, 54: 7, 28: 133, 33: 24, 34: 5, 36: 227, 35: 65, 37: 20, 38: 14, 39: 41, 40: 11, 26: 95, 41: 30, 42: 89, 43: 4, 44: 44, 45: 8, 46: 59, 47: 146, 48: 21, 49: 15, 50: 14, 51: 24, 52: 1, 53: 39, 29: 150, 55: 64, 56: 24, 57: 13, 58: 38, 59: 94, 60: 9, 62: 17, 27: 102, 63: 1, 64: 1, 65: 2, 66: 44, 72: 164, 73: 13, 75: 31, 76: 2, 78: 41, 79: 53, 77: 25, 80: 59, 81: 18, 83: 8, 91: 2, 67: 17, 84: 1, 85: 1, 86: 122, 71: 109, 87: 195, 88: 1, 89: 29, 90: 72, 93: 1, 92: 5, 82: 1, 94: 80, 95: 2, 99: 24, 96: 2, 100: 5, 98: 8, 31: 15, 102: 5, 103: 68, 115: 3, 116: 2, 104: 30, 105: 3, 106: 9, 68: 275, 117: 1, 118: 1, 119: 1, 107: 4, 108: 2, 109: 190, 110: 95, 111: 29, 120: 8, 112: 1, 121: 9, 122: 213, 113: 89, 123: 1, 124: 3, 114: 1, 130: 13, 126: 25, 127: 132, 128: 80, 129: 4, 132: 29, 133: 10, 134: 2, 135: 7, 136
# ...

# %%
from_counts = from_counter.values()
to_counts = to_counter.values()
print("Most votes by a user",max(from_counts))
print("Most voted for",max(to_counts))
('Most votes by a user', 893)
('Most voted for', 457)

plt.hist(from_counts)
plt.title("How Many Votes Made By Users")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
# Out:
# Most votes by a user 893
# Most voted for 457

# %%
plt.hist(to_counts)
plt.title("How Many Votes Made for User")
plt.xlabel("Value")
plt.ylabel("Frequency")
plt.show()
