# %%
install.packages("microbenchmark", repos="http://cran.us.r-project.org")
library(microbenchmark)
x <- runif(125) 
microbenchmark( mean(x) )
# Out:
# Installing package into 'C:/Users/Test/Documents/R/win-library/3.4'
# (as 'lib' is unspecified)
# package 'microbenchmark' successfully unpacked and MD5 sums checked
#
# The downloaded binary packages are in
# 	C:\Users\Test\AppData\Local\Temp\RtmpUlHFRk\downloaded_packages
# Warning message:
# "package 'microbenchmark' was built under R version 3.4.3"
#     expr    time
# 1   mean(x) 195651
# 2   mean(x)   6415
# 3   mean(x)   4812
# 4   mean(x)   4811
# 5   mean(x)   3850
# 6   mean(x)   5774
# 7   mean(x)   3208
# 8   mean(x)   4170
# 9   mean(x)   3850
# 10  mean(x)   3849
# 11  mean(x)   3529
# 12  mean(x)   3850
# 13  mean(x)   3849
# 14  mean(x)   3529
# 15  mean(x)   4170
# 16  mean(x)   3850
# 17  mean(x)   4170
# 18  mean(x)   3529
# 19  mean(x)   3208
# 20  mean(x)   3209
# 21  mean(x)   3529
# 22  mean(x)   3208
# 23  mean(x)   3529
# 24  mean(x)   3528
# 25  mean(x)   3529
# 26  mean(x)   3529
# 27  mean(x)   3208
# 28  mean(x)   4171
# 29  mean(x)   3208
# 30  mean(x)   3209
# ... ...     ...
# 71  mean(x)  3529
# 72  mean(x)  3850
# 73  mean(x)  3208
# 74  mean(x)  3208
# 75  mean(x)  3528
# 76  mean(x)  3529
# 77  mean(x)  3529
# 78  mean(x)  3208
# 79  mean(x)  3208
# 80  mean(x)  3529
# 81  mean(x) 15075
# 82  mean(x)  3529
# 83  mean(x)  3529
# 84  mean(x) 12509
# 85  mean(x)  3208
# 86  mean(x)  3529
# 87  mean(x)  3529
# 88  mean(x)  3529
# 89  mean(x)  3208
# 90  mean(x)  3208
# 91  mean(x)  3529
# 92  mean(x)  3208
# 93  mean(x) 16359
# 94  mean(x)  3528
# 95  mean(x) 12510
# 96  mean(x)  3208
# 97  mean(x)  3529
# 98  mean(x) 12188
# 99  mean(x)  3209
# 100 mean(x)  3208
