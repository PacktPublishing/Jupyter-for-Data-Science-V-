# %%
import pyspark
if not 'sc' in globals():
    sc = pyspark.SparkContext()

text_file = sc.textFile("2 Spark File Words.ipynb")
counts = text_file.flatMap(lambda line: line.split(" ")) \
             .map(lambda word: (word, 1)) \
             .reduceByKey(lambda a, b: a + b)
for x in counts.collect():
    print (x)
# Out:
# ('', 804)
# ('"cells":', 1)
# ('[', 4)
# ('"code",', 2)
# ('"outputs":', 2)
# ('"name":', 4)
# ('"stdout",', 1)
# ('"output_type":', 1)
# ('"text":', 1)
# ('"(\'\',', 1)
# ('"(\'\\"cells\\":\',', 1)
# ('4)\\n",', 3)
# ('2)\\n",', 26)
# ('"(\'3,\',', 1)
# ('"(\'\\"outputs\\":\',', 1)
# ('"(\'5)\\",\',', 1)
# ('"(\'\\"output_type\\":\',', 1)
# ('"(\'\\"\\\\\\\\u001b\',', 1)
# ('"(\'\\\\\\\\u001b5\\\\\\\\u001b\\\\\\\\n\\\\\\\\u001b\',', 1)
# ('"(\'counts\',', 1)
# ('"(\'=\',', 1)
# ('"(\'text_file.flatMap(lambda\',', 1)
# ('"(\'1))\',', 1)
# ('"(\'b:\',', 1)
# ('"(\'b)\\\\\\\\u001b\\\\\\\\n\\\\\\\\u001b\',', 1)
# ('"(\'^\\\\\\\\u001b\\\\\\\\n\\\\\\\\u001bIndentationError\\\\\\\\u001b\\\\\\\\u001b:\\\\\\\\u001b\',', 1)
# ('"(\'indent\\\\\\\\n\\"\',', 1)
# ('"(\'}\',', 1)
# ('"(\'\\"import\',', 1)
# ('"(\'pyspark\\\\\\\\n\\",\',', 1)
# ('"(\'in\',', 1)
# ('"(\'\\"\',', 1)
# ('7)\\n",', 1)
# ('"(\'sc\',', 1)
# ('"(\'text_file\',', 1)
# ('"(\'b)\\\\\\\\n\\",\',', 1)
# ('"(\'\\"collapsed\\":\',', 1)
# ('"(\'true\',', 1)
# ('"(\'[],\',', 1)
# ('"(\'3\\",\',', 1)
# ('"(\'\\"python\\",\',', 1)
# ('3)\\n",', 3)
# ('"(\'\\"name\\":\',', 1)
# ('"(\'\\"python3\\"\',', 1)
# ('"(\'\\"version\\":\',', 1)
# ('"(\'\\".py\\",\',', 1)
# ('"(\'\\"nbconvert_exporter\\":\',', 1)
# ('"(\'\\"3.6.3\\"\',', 1)
# ('"(\'4,\',', 1)
# ('"(\'\\"cell_type\\":\',', 1)
# ('"(\'\\"ename\\":\',', 1)
# ('"(\'indent\',', 1)
# ('"(\'(<ipython-input-3-7a0704af6c87>,\',', 1)
# ('"(\'\\"traceback\\":\',', 1)
# ('"(\'File\',', 1)
# ('"(\'\\\\\\\\u001b\\\\\\\\\\"<ipython-input-3-7a0704af6c87>\\\\\\\\\\"\\\\\\\\u001b,\',', 1)
# ('"(\'line:\',', 1)
# ('"(\'\\\\\\\\\\"))\',', 1)
# ('"(\'.map(lambda\',', 1)
# ('"(\'.reduceByKey(lambda\',', 1)
# ('"(\'a\',', 1)
# ('"(\']\',', 1)
# ('"(\'],\',', 1)
# ('"(\'\\"if\',', 1)
# ('"(\'not\',', 1)
# ('"(\'x\\"\',', 1)
# ('"(\'},\',', 1)
# ('"(\'null,\',', 1)
# ('"(\'\\"language\\":\',', 1)
# ('"(\'\\"codemirror_mode\\":\',', 1)
# ('"(\'\\"file_extension\\":\',', 1)
# ('"(\'\\"mimetype\\":\',', 1)
# ('"(\'\\"nbformat\\":\',', 1)
# ('"(\'2\',', 1)
# ('1)\\n"', 1)
# ('}', 4)
# ('"import', 1)
# ('pyspark\\n",', 1)
# ("'sc'", 1)
# ('in', 2)
# ('globals():\\n",', 1)
# ('"', 4)
# ('sc', 1)
# ('=', 3)
# ('"\\n",', 1)
# ('Spark', 1)
# ('Words.ipynb\\")\\n",', 1)
# ('"counts', 1)
# ('text_file.flatMap(lambda', 1)
# ('word:', 1)
# ('(word,', 1)
# ('1))', 1)
# ('b:', 1)
# ('b)\\n",', 1)
# ('print', 1)
# ('(x)"', 1)
# ('"collapsed":', 1)
# ('true', 1)
# ('[],', 1)
# ('[]', 1)
# ('"display_name":', 1)
# ('3",', 1)
# ('"python",', 3)
# ('"python3"', 1)
# ('"version":', 2)
# ('".py",', 1)
# ('"text/x-python",', 1)
# ('"nbconvert_exporter":', 1)
# ('"ipython3",', 1)
# ('"3.6.3"', 1)
# ('4,', 1)
# ('"nbformat_minor":', 1)
# ('{', 9)
# ('"cell_type":', 2)
# ('"execution_count":', 2)
# ('5,', 1)
# ('"metadata":', 3)
# ('{},', 1)
# ('"stream",', 1)
# ('228)\\n",', 1)
# ('1)\\n",', 63)
# ('"(\'[\',', 1)
# ('"(\'\\"code\\",\',', 1)
# ('"(\'\\"IndentationError\\",\',', 1)
# ('"(\'\\"evalue\\":\',', 1)
# ('"(\'\\"unexpected\',', 1)
# ('"(\'line\',', 1)
# ('"(\'\\"error\\",\',', 1)
# ('"(\'word:\',', 1)
# ('"(\'(word,\',', 1)
# ('"(\'unexpected\',', 1)
# ('"(\\"\'sc\'\\",', 1)
# ('"(\'globals():\\\\\\\\n\\",\',', 1)
# ('"(\'sc.textFile(\\\\\\\\\\"Spark\',', 1)
# ('"(\'Words.ipynb\\\\\\\\\\")\\\\\\\\n\\",\',', 1)
# ('"(\'print\',', 1)
# ('"(\'[]\',', 1)
# ('"(\'\\"display_name\\":\',', 1)
# ('"(\'\\"text/x-python\\",\',', 1)
# ('"(\'\\"ipython3\\",\',', 1)
# ('"(\'\\"nbformat_minor\\":\',', 1)
# ('"(\'{\',', 1)
# ('9)\\n",', 1)
# ('"(\'\\"execution_count\\":\',', 1)
# ('"(\'\\"metadata\\":\',', 1)
# ('"(\'{},\',', 1)
# ('"(\'line.split(\\\\\\\\\\"\',', 1)
# ('"(\'a,\',', 1)
# ('"(\'+\',', 1)
# ('"(\'\\"source\\":\',', 1)
# ('"(\'pyspark.SparkContext()\\\\\\\\n\\",\',', 1)
# ('"(\'\\\\\\\\\\\\\\\\\\\\\\\\n\\",\',', 1)
# ('"(\'for\',', 1)
# ('"(\'x\',', 1)
# ('"(\'counts.collect():\\\\\\\\n\\",\',', 1)
# ('5)\\n",', 1)
# ('"(\'\\"kernelspec\\":\',', 1)
# ('"(\'\\"Python\',', 1)
# ('"(\'\\"language_info\\":\',', 1)
# ('"(\'\\"ipython\\",\',', 1)
# ('"(\'3\',', 1)
# ('"(\'\\"pygments_lexer\\":\',', 1)
# (']', 2)
# ('],', 2)
# ('"source":', 2)
# ('"if', 1)
# ('not', 1)
# ('pyspark.SparkContext()\\n",', 1)
# ('"text_file', 1)
# ('sc.textFile(\\"2', 1)
# ('File', 1)
# ('line:', 1)
# ('line.split(\\"', 1)
# ('\\"))', 1)
# ('\\\\\\n",', 2)
# ('.map(lambda', 1)
# ('.reduceByKey(lambda', 1)
# ('a,', 1)
# ('a', 1)
# ('+', 1)
# ('"for', 1)
# ('x', 1)
# ('counts.collect():\\n",', 1)
# ('},', 5)
# ('null,', 1)
# ('"kernelspec":', 1)
# ('"Python', 1)
# ('"language":', 1)
# ('"language_info":', 1)
# ('"codemirror_mode":', 1)
# ('"ipython",', 1)
# ('3', 1)
# ('"file_extension":', 1)
# ('"mimetype":', 1)
# ('"pygments_lexer":', 1)
# ('"nbformat":', 1)
# ('2', 1)
